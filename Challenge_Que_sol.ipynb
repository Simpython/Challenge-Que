# %% [markdown]
# <a href="https://colab.research.google.com/github/Simpython/Challenge-Que/blob/main/Challenge_Que_sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Heterogeneous list
L = ["Ram", 1, "Shyam", 2, "Aman", 3]

print("Original List:", L)

# Sort using string representation
L.sort(key=str)

print("Sorted List:", L)
# Out:
# Original List: ['Ram', 1, 'Shyam', 2, 'Aman', 3]
# Sorted List: [1, 2, 3, 'Aman', 'Ram', 'Shyam']
